# %%
import pyspark
from pyspark.sql.types import BooleanType
from pyspark.sql.functions import udf, split, col, regexp_extract,regexp_replace
from pyspark.sql import functions as F
from pyspark.sql import SparkSession, DataFrame
from pyspark.ml import Pipeline
from pyspark.ml.feature import  NGram, Tokenizer,CountVectorizer, StopWordsRemover
import pandas as pd 
from functools import reduce
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression 
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix

# %%
spark=SparkSession.builder.getOrCreate()

# %%
test_dataset = spark.read.csv('/healthcare-dataset-stroke-data/test_2v.csv', header=True, inferSchema=True)
train_dataset = spark.read.csv('/healthcare-dataset-stroke-data/train_2v.csv', header=True, inferSchema=True)

# %%
test_dataset.show(truncate=0)
# Out:
# +-----+------+----+------------+-------------+------------+-------------+--------------+-----------------+----+---------------+
# |id   |gender|age |hypertension|heart_disease|ever_married|work_type    |Residence_type|avg_glucose_level|bmi |smoking_status |
# +-----+------+----+------------+-------------+------------+-------------+--------------+-----------------+----+---------------+
# |36306|Male  |80.0|0           |0            |Yes         |Private      |Urban         |83.84            |21.1|formerly smoked|
# |61829|Female|74.0|0           |1            |Yes         |Self-employed|Rural         |179.5            |26.0|formerly smoked|
# |14152|Female|14.0|0           |0            |No          |children     |Rural         |95.16            |21.2|null           |
# |12997|Male  |28.0|0           |0            |No          |Private      |Urban         |94.76            |23.4|null           |
# |40801|Female|63.0|0           |0            |Yes         |Govt_job     |Rural         |83.57            |27.6|never smoked   |
# |9348 |Female|66.0|1           |0            |Yes         |Private      |Urban         |219.98           |32.2|never smoked   |
# |51550|Female|49.0|0           |0            |Yes         |Self-employed|Rural         |74.03            |25.1|null           |
# |60512|Male  |46.0|0           |0            |Yes         |Govt_job     |Urban         |120.8            |32.5|never smoked   |
# |31309|Female|75.0|0           |0            |Yes         |Self-employed|Rural         |78.71            |28.0|never smoked   |
# |39199|Male  |75.0|0           |0            |Yes         |Self-employed|Urban         |77.2             |25.7|smokes         |
# |15160|Female|17.0|0           |0            |No          |Private      |Rural         |78.16            |21.9|null           |
# |21705|Female|10.0|0           |0            |No          |children     |Urban         |107.23           |19.4|null           |
# |19042|Female|47.0|0           |0            |Yes         |Private      |Rural         |91.6             |26.7|never smoked   |
# |12249|Female|42.0|0           |0            |Yes         |Private      |Urban         |83.05            |32.3|null           |
# |33104|Female|67.0|0           |0            |Yes         |Govt_job     |Urban         |236.6            |24.2|never smoked   |
# |55264|Female|52.0|0           |0            |No          |Self-employed|Urban         |109.49           |24.5|never smoked   |
# |29445|Male  |73.0|0           |0            |Yes         |Self-employed|Rural         |109.66           |40.0|null           |
# |49013|Female|19.0|0           |0            |No          |Private      |Rural         |88.51            |22.1|null           |
# |276  |Male  |15.0|0           |0            |No          |children     |Rural         |101.36           |22.3|null           |
# |47721|Female|37.0|0           |0            |Yes         |Govt_job     |Urban         |165.44           |36.1|formerly smoked|
# +-----+------+----+------------+-------------+------------+-------------+--------------+-----------------+----+---------------+
# only showing top 20 rows

# %%
train_dataset.show(truncate=0)
# Out:
# +-----+------+----+------------+-------------+------------+-------------+--------------+-----------------+----+---------------+------+
# |id   |gender|age |hypertension|heart_disease|ever_married|work_type    |Residence_type|avg_glucose_level|bmi |smoking_status |stroke|
# +-----+------+----+------------+-------------+------------+-------------+--------------+-----------------+----+---------------+------+
# |30669|Male  |3.0 |0           |0            |No          |children     |Rural         |95.12            |18.0|null           |0     |
# |30468|Male  |58.0|1           |0            |Yes         |Private      |Urban         |87.96            |39.2|never smoked   |0     |
# |16523|Female|8.0 |0           |0            |No          |Private      |Urban         |110.89           |17.6|null           |0     |
# |56543|Female|70.0|0           |0            |Yes         |Private      |Rural         |69.04            |35.9|formerly smoked|0     |
# |46136|Male  |14.0|0           |0            |No          |Never_worked |Rural         |161.28           |19.1|null           |0     |
# |32257|Female|47.0|0           |0            |Yes         |Private      |Urban         |210.95           |50.1|null           |0     |
# |52800|Female|52.0|0           |0            |Yes         |Private      |Urban         |77.59            |17.7|formerly smoked|0     |
# |41413|Female|75.0|0           |1            |Yes         |Self-employed|Rural         |243.53           |27.0|never smoked   |0     |
# |15266|Female|32.0|0           |0            |Yes         |Private      |Rural         |77.67            |32.3|smokes         |0     |
# |28674|Female|74.0|1           |0            |Yes         |Self-employed|Urban         |205.84           |54.6|never smoked   |0     |
# |10460|Female|79.0|0           |0            |Yes         |Govt_job     |Urban         |77.08            |35.0|null           |0     |
# |64908|Male  |79.0|0           |1            |Yes         |Private      |Urban         |57.08            |22.0|formerly smoked|0     |
# |63884|Female|37.0|0           |0            |Yes         |Private      |Rural         |162.96           |39.4|never smoked   |0     |
# |37893|Female|37.0|0           |0            |Yes         |Private      |Rural         |73.5             |26.1|formerly smoked|0     |
# |67855|Female|40.0|0           |0            |Yes         |Private      |Rural         |95.04            |42.4|never smoked   |0     |
# |25774|Male  |35.0|0           |0            |No          |Private      |Rural         |85.37            |33.0|never smoked   |0     |
# |19584|Female|20.0|0           |0            |No          |Private      |Urban         |84.62            |19.7|smokes         |0     |
# |24447|Female|42.0|0           |0            |Yes         |Private      |Rural         |82.67            |22.5|never smoked   |0     |
# |49589|Female|44.0|0           |0            |Yes         |Govt_job     |Urban         |57.33            |24.6|smokes         |0     |
# |17986|Female|79.0|0           |1            |Yes         |Self-employed|Urban         |67.84            |25.2|smokes         |0     |
# +-----+------+----+------------+-------------+------------+-------------+--------------+-----------------+----+---------------+------+
# only showing top 20 rows

# %%
test_dataset.columns
# Out:
# ['id',
#  'gender',
#  'age',
#  'hypertension',
#  'heart_disease',
#  'ever_married',
#  'work_type',
#  'Residence_type',
#  'avg_glucose_level',
#  'bmi',
#  'smoking_status']

# %%
def count_empty(df,sort=True):
    """
    Counts number of nulls and nans in each column
    """
    df = df.select([F.count(F.when(F.isnull(c), c)).alias(c) for (c,c_type) in df.dtypes ]).toPandas()

    if len(df) == 0:
        print("There are no any missing values!")
        return None

    if sort:
        return df.rename(index={0: 'count'}).T.sort_values("count",ascending=False)

    return df

# %%
count_empty(test_dataset)
# Out:
#                    count
# smoking_status      5751
# bmi                  591
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0

# %%
count_empty(train_dataset)
# Out:
#                    count
# smoking_status     13292
# bmi                 1462
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# stroke                 0

# %%
test_dataset = test_dataset.toPandas()
train_dataset = train_dataset.toPandas()

# %%
combined_dataset = pd.concat([test_dataset, train_dataset], sort=False, ignore_index=True)

# %%
combined_dataset.head(50)
# Out:
#        id  gender   age  hypertension  heart_disease ever_married  \
# 0   36306    Male  80.0             0              0          Yes
# 1   61829  Female  74.0             0              1          Yes
# 2   14152  Female  14.0             0              0           No
# 3   12997    Male  28.0             0              0           No
# 4   40801  Female  63.0             0              0          Yes
# 5    9348  Female  66.0             1              0          Yes
# 6   51550  Female  49.0             0              0          Yes
# 7   60512    Male  46.0             0              0          Yes
# 8   31309  Female  75.0             0              0          Yes
# 9   39199    Male  75.0             0              0          Yes
# 10  15160  Female  17.0             0              0           No
# 11  21705  Female  10.0             0              0           No
# 12  19042  Female  47.0             0              0          Yes
# 13  12249  Female  42.0             0              0          Yes
# 14  33104  Female  67.0             0              0          Yes
# 15  55264  Female  52.0             0              0           No
# 16  29445    Male  73.0             0              0          Yes
# 17  49013  Female  19.0             0              0           No
# 18    276    Male  15.0             0              0           No
# 19  47721  Female  37.0             0              0          Yes
# 20  19656    Male  59.0             1              0          Yes
# 21  35806    Male  45.0             0              0          Yes
# 22  70637  Female  44.0             0              0          Yes
# 23  62010  Female  13.0             0              0           No
# 24  67576  Female  82.0             0              0          Yes
# 25  31774    Male  66.0             1              1          Yes
# 26  43822    Male  42.0             0              0          Yes
# 27  27445  Female  47.0             0              0          Yes
# 28  35817    Male  57.0             0              0          Yes
# 29  26363    Male  75.0             0              0          Yes
# 30  44463    Male  44.0             1              0          Yes
# 31  17002    Male  64.0             0              1          Yes
# 32  55223  Female  15.0             0              0           No
# 33  42974  Female  13.0             0              0           No
# 34  51133  Female   7.0             0              0           No
# 35  16974    Male  63.0             0              0          Yes
# 36  27813  Female  29.0             0              0          Yes
# 37  65408  Female  36.0             0              0          Yes
# 38  67455  Female  70.0             0              1          Yes
# 39   4577  Female  39.0             0              0           No
# 40  55641  Female  36.0             0              0          Yes
# 41  54834  Female   9.0             0              0           No
# 42   9699  Female  27.0             0              0          Yes
# 43  61811    Male  51.0             0              0          Yes
# 44  63620    Male  17.0             0              0           No
# 45  18723    Male  55.0             1              0          Yes
# 46  48538  Female  50.0             0              0          Yes
# 47  45891  Female  33.0             0              0          Yes
# 48  42487  Female  63.0             0              0          Yes
# 49  45698  Female  71.0             0              0          Yes
#
#         work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0         Private          Urban              83.84  21.1  formerly smoked
# 1   Self-employed          Rural             179.50  26.0  formerly smoked
# 2        children          Rural              95.16  21.2             None
# 3         Private          Urban              94.76  23.4             None
# 4        Govt_job          Rural              83.57  27.6     never smoked
# 5         Private          Urban             219.98  32.2     never smoked
# 6   Self-employed          Rural              74.03  25.1             None
# 7        Govt_job          Urban             120.80  32.5     never smoked
# 8   Self-employed          Rural              78.71  28.0     never smoked
# 9   Self-employed          Urban              77.20  25.7           smokes
# 10        Private          Rural              78.16  21.9             None
# 11       children          Urban             107.23  19.4             None
# 12        Private          Rural              91.60  26.7     never smoked
# 13        Private          Urban              83.05  32.3             None
# 14       Govt_job          Urban             236.60  24.2     never smoked
# 15  Self-employed          Urban             109.49  24.5     never smoked
# 16  Self-employed          Rural             109.66  40.0             None
# 17        Private          Rural              88.51  22.1             None
# 18       children          Rural             101.36  22.3             None
# 19       Govt_job          Urban             165.44  36.1  formerly smoked
# 20  Self-employed          Rural             101.06  33.3  formerly smoked
# 21        Private          Urban              81.54  36.3           smokes
# 22        Private          Rural             150.06  22.2     never smoked
# 23       children          Urban              87.79  20.5  formerly smoked
# 24        Private          Rural             205.80  36.5  formerly smoked
# 25        Private          Rural              93.79  33.1     never smoked
# 26       Govt_job          Rural              60.60  26.9             None
# 27        Private          Urban              94.80  40.6     never smoked
# 28        Private          Urban              75.12  27.7             None
# 29        Private          Urban             116.78  22.4           smokes
# 30        Private          Rural             150.14  35.1     never smoked
# 31        Private          Rural             212.68  25.5     never smoked
# 32       children          Rural             128.82  28.4  formerly smoked
# 33       children          Rural             147.95  18.7  formerly smoked
# 34       children          Urban              78.88  20.9             None
# 35  Self-employed          Rural              84.02  26.7           smokes
# 36        Private          Rural             116.33  33.5     never smoked
# 37        Private          Rural              97.92  44.7             None
# 38  Self-employed          Rural             132.56  33.7           smokes
# 39        Private          Rural             105.36  25.3             None
# 40        Private          Urban             116.69  27.8     never smoked
# 41  Self-employed          Rural              80.63  24.8             None
# 42        Private          Rural              65.85  21.6     never smoked
# 43        Private          Urban             192.53  33.7  formerly smoked
# 44        Private          Urban              58.17  20.3             None
# 45        Private          Rural              93.61  37.6     never smoked
# 46        Private          Urban              62.69  21.5  formerly smoked
# 47        Private          Urban              58.87  23.1           smokes
# 48        Private          Rural             133.70  26.3     never smoked
# 49       Govt_job          Urban             173.02  29.2  formerly smoked
#
#     stroke
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# 30     NaN
# 31     NaN
# 32     NaN
# 33     NaN
# 34     NaN
# 35     NaN
# 36     NaN
# 37     NaN
# 38     NaN
# 39     NaN
# 40     NaN
# 41     NaN
# 42     NaN
# 43     NaN
# 44     NaN
# 45     NaN
# 46     NaN
# 47     NaN
# 48     NaN
# 49     NaN

# %%
combined_dataset = spark.createDataFrame(combined_dataset)

# %%
combined_dataset.groupBy().max('age', 'avg_glucose_level', 'bmi').collect()
# Out:
# [Row(max(age)=82.0, max(avg_glucose_level)=291.05, max(bmi)=nan)]

# %%
combined_dataset.groupBy().min('age', 'avg_glucose_level', 'bmi').collect()
# Out:
# [Row(min(age)=0.08, min(avg_glucose_level)=55.0, min(bmi)=10.1)]

# %%
combined_dataset = combined_dataset.toPandas()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
combined_dataset['stroke'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('stroke')
ax[0].set_ylabel('')
sns.countplot('stroke',data=combined_dataset,ax=ax[1])
ax[1].set_title('stroke')
plt.show()

# %% [markdown]
# ### Observation
# 18% of the patients had stroke

# %%
#combined_dataset.groupby([''])

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
combined_dataset[combined_dataset['stroke']==0].age.plot.hist(ax=ax[0],color='green',bins=20,edgecolor='black')
ax[0].set_title('stroke= 0')
x1=list(range(0,100,5))
ax[0].set_xticks(x1)
combined_dataset[combined_dataset['stroke']==1].age.plot.hist(ax=ax[1],bins=20,edgecolor='black',color='red')
ax[1].set_title('stroke= 1')
x2=list(range(0,100,5))
ax[1].set_xticks(x2)
plt.show()

# %% [markdown]
# ### Observation
# + People under age 30 rarely had stroke
# + Older people were more prone to stroke

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
combined_dataset[['gender','stroke']].groupby(['gender']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Stroke vs Gender')
sns.countplot('gender',hue='stroke',data=combined_dataset,ax=ax[1])
ax[1].set_title('gender:No Stroke vs Had Stroke')
plt.show()

# %% [markdown]
# ### Observation
# More women had stroke than men

# %%
sns.catplot(x='smoking_status',y='avg_glucose_level',hue='stroke',data=combined_dataset, kind="bar")
plt.show()

# %% [markdown]
# ### Observation
# + People who have never smoked were the least likely to get stroke
# + People who formerly smoked had higher chance of getting stroke
# + People who currently smoked had the highest chance of getting stroke

# %%
sns.catplot(x='gender',y='bmi',hue='stroke',data=combined_dataset, kind="bar")
plt.show()

# %%
sns.catplot(x='heart_disease',y='bmi',hue='stroke',data=combined_dataset, kind="bar")
plt.show()

# %%
sns.catplot(x='hypertension',y='age',hue='stroke',data=combined_dataset, kind="bar")
plt.show()

# %%
sns.heatmap(train_dataset.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
combined_dataset.drop(['age', 'bmi', 'avg_glucose_level'], axis=1, inplace=True)

# %% [markdown]
# The data we have been working with has lots of missing data and is imbalanced

# %%
print ('Combined Data Shape: {}'.format(combined_dataset.shape))
# Out:
# Combined Data Shape: (62001, 9)

# %%
combined_dataset.isnull().sum()/len(combined_dataset)*100
# Out:
# id                 0.000000
# gender             0.000000
# hypertension       0.000000
# heart_disease      0.000000
# ever_married       0.000000
# work_type          0.000000
# Residence_type     0.000000
# smoking_status    30.714021
# stroke            30.001129
# dtype: float64

# %%
combined_dataset.head()
# Out:
#       id  gender  hypertension  heart_disease ever_married      work_type  \
# 0  36306    Male             0              0          Yes        Private
# 1  61829  Female             0              1          Yes  Self-employed
# 2  14152  Female             0              0           No       children
# 3  12997    Male             0              0           No        Private
# 4  40801  Female             0              0          Yes       Govt_job
#
#   Residence_type   smoking_status  stroke
# 0          Urban  formerly smoked     NaN
# 1          Rural  formerly smoked     NaN
# 2          Rural             None     NaN
# 3          Urban             None     NaN
# 4          Rural     never smoked     NaN

# %%
## Dropping Unwanted Columns
combined_dataset.drop(['age', 'bmi', 'avg_glucose_level'], axis=1, inplace=True)

# %% [markdown]
# ## Categorical Values
#
# Let's convert columns with continous values into categorical Values.
# + Age - The age of patients will be classified into five categories - 0-15, 16-35, 36-45, 46-65, 66 and above
# + BMI - will be classified in four categories - 0-18 as thin, 19-25 as normal, 26-30 as overweight and 31 and above as obese
# + Average Glucose Level - It will be considered that the data is a record of random blood sugar level measured in mg/dl. This will be classified in tree categories - 0-140, 140 and above 140

# %%
combined_dataset['age_band']=0
combined_dataset.loc[combined_dataset['age']<=15,'age_band']=0
combined_dataset.loc[(combined_dataset['age']>15)&(combined_dataset['age']<=35),'age_band']=1
combined_dataset.loc[(combined_dataset['age']>35)&(combined_dataset['age']<=45),'age_band']=2
combined_dataset.loc[(combined_dataset['age']>45)&(combined_dataset['age']<=65),'age_band']=3
combined_dataset.loc[combined_dataset['age']>65,'age_band']=4
combined_dataset.head(2)

# %%
combined_dataset['age_band'].value_counts().to_frame().style.background_gradient(cmap='summer')

# %%
sns.factorplot('age_band','stroke',data=combined_dataset, hue='gender')
plt.show()

# %%
combined_dataset['bmi_band']=0
combined_dataset.loc[combined_dataset['bmi']<=18,'bmi_band']=0
combined_dataset.loc[(combined_dataset['bmi']>18)&(combined_dataset['bmi']<=25),'bmi_band']=1
combined_dataset.loc[(combined_dataset['bmi']>25)&(combined_dataset['bmi']<=30),'bmi_band']=2
combined_dataset.loc[combined_dataset['bmi']>30,'bmi_band']=3
combined_dataset.head(2)

sns.factorplot('bmi_band','stroke',data=combined_dataset,hue='age_band')
plt.show()

# %%
combined_dataset['glucose_band']=0
combined_dataset.loc[combined_dataset['avg_glucose_level']<=140,'glucose_band']=0
combined_dataset.loc[combined_dataset['avg_glucose_level']==140,'glucose_band']=1
combined_dataset.loc[combined_dataset['avg_glucose_level']>140,'glucose_band']=2
combined_dataset.head(2)

sns.factorplot('glucose_band','stroke',data=combined_dataset,hue='gender')
plt.show()

# %%
## Dropping Unwanted Columns
combined_dataset.drop(['age', 'bmi', 'avg_glucose_level'], axis=1, inplace=True)

# %%
combined_dataset.head(20)

# %%
combined_dataset['gender'].replace(['Male','Female'],[0,1],inplace=True)
combined_dataset['smoking_status'].replace(['formerly smoked','never smoked','smokes'],[0,1,2],inplace=True)

# %%
combined_dataset.head()

# %%
## Dropping Unwanted Columns
combined_dataset.drop(['age', 'bmi', 'avg_glucose_level'], axis=1, inplace=True)

# %%
sns.heatmap(combined_dataset.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) 
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# ## Predictive Modeling

# %% [markdown]
# #### splitting the data, 70% for training and 30% for testing

# %%
feature_col_names = ['id','glucose_band','heart_disease','hypertension','gender','bmi_band','age_band']
predicted_class_names = ['stroke']

X = combined_dataset[feature_col_names].values     # predictor feature columns (8 x m ) 
y = combined_dataset[predicted_class_names].values  # predicted class (1 = true, 0 = false) column (1 x m)
split_test_size = 0.30


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = split_test_size, random_state = 42)

# %%
combined_dataset.head()

# %%
train,test=train_test_split(combined_dataset,test_size=0.3,random_state=0,stratify=combined_dataset['stroke'])
train_X=train[train.columns[1:]]
train_Y=train[train.columns[:1]]
test_X=test[test.columns[1:]]
test_Y=test[test.columns[:1]]
X=combined_dataset[combined_dataset.columns[1:]]
Y=combined_dataset['stroke']
